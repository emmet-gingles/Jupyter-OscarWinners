# %%
# This project involves using Beautiful Soup to extract information relating to Oscar winners from Wikipedia pages. In total 
# six different pages will be accessed in order to obtain the following:
# 1. Best Picture 
# 2. Best Director
# 3. Best Actor
# 4. Best Actress
# 5. Best Supporting Actor
# 6. Best Supporting Actress
# Once the data has been retrieved from each page, it will be stored in dataframes. I will then connect to MySQL, create tables
# and insert the data there. Finally I will run queries on the database to provide useful insight.

# %%
import urllib2;                    # for retrieving the contents of a page
from bs4 import BeautifulSoup;     # for parsing the contents of a page to HTML
import pandas as pd                # for creating dataframes

# %%
# function that takes in a URL and returns the contents of the page
def loadPage(url):
    page = urllib2.urlopen(url)
    data = BeautifulSoup(page, "lxml")
    return data

# %%
# Page 1- Best Picture
# Call function to read in URL and retrieve data from the page
data = loadPage("https://en.wikipedia.org/wiki/Academy_Award_for_Best_Picture")
# from the data get all the tables that have the following class
tables = data.findAll("table", class_= "wikitable")

# %%
# There are tables for each decade starting from the 1920's. We want to go through each table and extract the appropriate information
# Create empty lists for each film and nominee
films = []
nominees = []
# There are ten tables so we use range to keep track 
for i in range(0, 11):
    # For each table get each row with the following style
    for row in tables[i].findAll("tr", style="background:#FAEB86"):
        # Get each cell within that row
        cells = row.findAll('td')
        # Get the text from within the first cell, encode it to utf-8 and add it to the films list
        if(len(cells) > 0):        
            film = cells[0].find(text=True).encode('utf-8').strip()
            films.append(film)
            # Get the text from within the second cell, encode it and add it to the list of nominees
        if(len(cells) > 1):      
            nominee = cells[1].findAll(text=True)[:-1]
            nominees.append("".join(nominee).encode('utf-8').strip() )

# %%
# Here we extract the years. Years can be different formats depending on how far back they are ie. 1927/28, 1927/1928, 1928
# Create an empty list for each year
years = []
for i in range(0, 11):  
    # For each table row get each cell with the following style
    for row in tables[i].findAll("td", style="text-align:center"):
            # Get each link within that row
            cells = row.findAll('a')
            # If year is all in one link and in a format like 1927/28 then we want the first two and last two charaters so 
            # that it will be 1928
            if(len(cells[0].find(text=True)) == 7):
                year = cells[0].find(text=True)[0:2] + cells[0].find(text=True)[5:7]
            # If year is in two links and the second link has four numbers ie. 1927/1928 then we want the second link
            elif(len(cells[1].find(text=True)) == 4):       
                if (cells[1].find(text=True).isnumeric()):
                    year = cells[1].find(text=True)
            # If the year is in two links and the second link has two numbers ie. 1927/28 then we want the first two characters
            # of the first link and the last two of the second link
            elif(len(cells[1].find(text=True)) == 2):
                if (cells[1].find(text=True).isnumeric()):
                    year = cells[0].find(text=True)[0:2] + cells[1].find(text=True)
            # Else the year is in a standard format ie. 1928 so get four characters
            else:
                year = cells[0].find(text=True)[0:4]
            # add year to list of years
            years.append(year)

# %%
# Check the length of each list. They are all the same
print(len(films))
print(len(nominees))
print(len(years))
# Out:
# 90
# 90
# 90

# %%
# Create a data frame for storing each list
df_picture = pd.DataFrame()
df_picture["Year"] = pd.to_numeric(years, errors='coerce')
df_picture["Film"] = films
df_picture["Nominee"] = nominees
df_picture
# Out:
#     Year                                             Film  \
# 0   1928                                            Wings
# 1   1929                              The Broadway Melody
# 2   1930                   All Quiet on the Western Front
# 3   1931                                         Cimarron
# 4   1932                                      Grand Hotel
# 5   1933                                        Cavalcade
# 6   1934                            It Happened One Night
# 7   1935                             Mutiny on the Bounty
# 8   1936                               The Great Ziegfeld
# 9   1937                           The Life of Emile Zola
# 10  1938                       You Can't Take It with You
# 11  1939                               Gone with the Wind
# 12  1940                                          Rebecca
# 13  1941                          How Green Was My Valley
# 14  1942                                     Mrs. Miniver
# 15  1943                                       Casablanca
# 16  1944                                     Going My Way
# 17  1945                                 The Lost Weekend
# 18  1946                      The Best Years of Our Lives
# 19  1947                            Gentleman's Agreement
# 20  1948                                           Hamlet
# 21  1949                               All the King's Men
# 22  1950                                    All About Eve
# 23  1951                             An American in Paris
# 24  1952                       The Greatest Show on Earth
# 25  1953                            From Here to Eternity
# 26  1954                                On the Waterfront
# 27  1955                                            Marty
# 28  1956                      Around the World in 80 Days
# 29  1957                     The Bridge on the River Kwai
# ..   ...                                              ...
# 60  1988                                         Rain Man
# 61  1989                               Driving Miss Daisy
# 62  1990                               Dances with Wolves
# 63  1991                         The Silence of the Lambs
# 64  1992                                       Unforgiven
# 65  1993                                 Schindler's List
# 66  1994                                     Forrest Gump
# 67  1995                                       Braveheart
# 68  1996                              The English Patient
# 69  1997                                          Titanic
# 70  1998                              Shakespeare in Love
# 71  1999                                  American Beauty
# 72  2000                                        Gladiator
# 73  2001                                 A Beautiful Mind
# 74  2002                                          Chicago
# 75  2003    The Lord of the Rings: The Return of the King
# 76  2004                              Million Dollar Baby
# 77  2005                                            Crash
# 78  2006                                     The Departed
# 79  2007                           No Country for Old Men
# 80  2008                              Slumdog Millionaire
# 81  2009                                  The Hurt Locker
# 82  2010                                The King's Speech
# 83  2011                                       The Artist
# 84  2012                                             Argo
# 85  2013                                 12 Years a Slave
# 86  2014  Birdman or (The Unexpected Virtue of Ignorance)
# 87  2015                                        Spotlight
# 88  2016                                        Moonlight
# 89  2017                               The Shape of Water
#
#                                               Nominee
# 0                              Paramount Famous Lasky
# 1                                 Metro-Goldwyn-Mayer
# 2                                           Universal
# 3                                           RKO Radio
# 4                                 Metro-Goldwyn-Mayer
# 5                                                 Fox
# 6                                            Columbia
# 7                                 Metro-Goldwyn-Mayer
# 8                                 Metro-Goldwyn-Mayer
# 9                                        Warner Bros.
# 10                                           Columbia
# 11                    Selznick International Pictures
# 12                    Selznick International Pictures
# 13                                   20th Century-Fox
# 14                                Metro-Goldwyn-Mayer
# 15                                       Warner Bros.
# 16                                          Paramount
# 17                                          Paramount
# 18                         Samuel Goldwyn Productions
# 19                                   20th Century-Fox
# 20                    J. Arthur Rank-Two Cities Films
# 21                          Robert Rossen Productions
# 22                                   20th Century-Fox
# 23                                       Arthur Freed
# 24                                   Cecil B. DeMille
# 25                                        Buddy Adler
# 26                                        Sam Spiegel
# 27                                       Harold Hecht
# 28                                       Michael Todd
# 29                                        Sam Spiegel
# ..                                                ...
# 60                                       Mark Johnson
# 61             Richard D. Zanuck and Lili Fini Zanuck
# 62                       Jim Wilson and Kevin Costner
# 63          Edward Saxon, Kenneth Utt, and Ron Bozman
# 64                                     Clint Eastwood
# 65  Steven Spielberg, Gerald R. Molen, and Branko ...
# 66     Wendy Finerman, Steve Tisch, and Steve Starkey
# 67         Mel Gibson, Alan Ladd Jr., and Bruce Davey
# 68                                        Saul Zaentz
# 69                       James Cameron and Jon Landau
# 70  David Parfitt, Donna Gigliotti, Harvey Weinste...
# 71                          Bruce Cohen and Dan Jinks
# 72    Douglas Wick, David Franzoni, and Branko Lustig
# 73                        Brian Grazer and Ron Howard
# 74                                    Martin Richards
# 75   Barrie M. Osborne, Peter Jackson, and Fran Walsh
# 76  Clint Eastwood, Albert S. Ruddy, and Tom Rosen...
# 77                     Paul Haggis and Cathy Schulman
# 78                                        Graham King
# 79             Scott Rudin, Joel Coen, and Ethan Coen
# 80                                   Christian Colson
# 81  Kathryn Bigelow, Mark Boal, Nicolas Chartier, ...
# 82      Iain Canning, Emile Sherman, and Gareth Unwin
# 83                                    Thomas Langmann
# 84      Grant Heslov, Ben Affleck, and George Clooney
# 85  Brad Pitt, Dede Gardner, Jeremy Kleiner, Steve...
# 86  Alejandro G. Iñárritu, John Lesher, and James ...
# 87  Blye Pagon Faust, Steve Golin, Nicole Rocklin,...
# 88   Adele Romanski, Dede Gardner, and Jeremy Kleiner
# 89               Guillermo del Toro and J. Miles Dale
#
# [90 rows x 3 columns]

# %%
# Page2 - Best Director
data = loadPage("https://en.wikipedia.org/wiki/Academy_Award_for_Best_Director")
tables = data.findAll("table", class_= "wikitable sortable")

# %%
# Here we extract each film and its director. All the data is stored in one table.
# Create empty lists for storing each film and director
films =[]
directors = []
# Get each row within the table
for row in tables[0].findAll("tr"):
        # Get each cell within that row with the following style
        cells = row.findAll("td", style="background:#FAEB86;")
        # For the first year there was two categories of winners so we want to include that information. It is inside a span tag.
        # FindAll() gets all the text within the cell including child tags. 
        #Finally use join() to merge the text into one string and add it to the list of direcors
        if(len(cells) > 0):
            director = cells[0].findAll(text=True)[:-1]
            directors.append("".join(director).encode('utf-8').strip())  
        # Get the film from the second cell and add it to the list of films
        if(len(cells) > 1):
            film = cells[1].find(text=True).encode('utf-8').strip() 
            films.append(film)

# %%
# Here we extract the years.
years = []
for row in tables[0].findAll("th", scope="row"):
    cells = row.findAll('a')     
    if(len(cells[0].find(text=True)) == 7):
        year = cells[0].find(text=True)[0:2] + cells[0].find(text=True)[5:7]
    elif(len(cells[1].find(text=True)) == 4):       
        if (cells[1].find(text=True).isnumeric()):
            year = cells[1].find(text=True)  
    elif(len(cells[1].find(text=True)) == 2):
        if (cells[1].find(text=True).isnumeric()):
            year = cells[0].find(text=True)[0:2] + cells[1].find(text=True)
    else:
        year = cells[0].find(text=True)[0:4]
    years.append(year)

# %%
# Check the length of each list. Due to the 1st Oscars having multiple awards they are not the same length
print(len(films))
print(len(directors))
print(len(years))
# Out:
# 91
# 91
# 90

# %%
# To amend this lets insert a year at the position 1 with the same value as the position 0
years.insert(1, years[0])

# %%
# Now they are all the same length
print(len(films))
print(len(directors))
print(len(years))
# Out:
# 91
# 91
# 91

# %%
# Create a data frame for storing each list and print it
df_directors = pd.DataFrame()
df_directors["Year"] = pd.to_numeric(years, errors='coerce')
df_directors["Director"] = directors
df_directors["Film"] = films
# Look at the data frame.
df_directors
# Out:
#     Year                  Director  \
# 0   1928  Frank Borzage (Dramatic)
# 1   1928  Lewis Milestone (Comedy)
# 2   1929               Frank Lloyd
# 3   1930           Lewis Milestone
# 4   1931             Norman Taurog
# 5   1932             Frank Borzage
# 6   1933               Frank Lloyd
# 7   1934               Frank Capra
# 8   1935                 John Ford
# 9   1936               Frank Capra
# 10  1937               Leo McCarey
# 11  1938               Frank Capra
# 12  1939            Victor Fleming
# 13  1940                 John Ford
# 14  1941                 John Ford
# 15  1942             William Wyler
# 16  1943            Michael Curtiz
# 17  1944               Leo McCarey
# 18  1945              Billy Wilder
# 19  1946             William Wyler
# 20  1947                Elia Kazan
# 21  1948               John Huston
# 22  1949      Joseph L. Mankiewicz
# 23  1950      Joseph L. Mankiewicz
# 24  1951            George Stevens
# 25  1952                 John Ford
# 26  1953            Fred Zinnemann
# 27  1954                Elia Kazan
# 28  1955              Delbert Mann
# 29  1956            George Stevens
# ..   ...                       ...
# 61  1988            Barry Levinson
# 62  1989              Oliver Stone
# 63  1990             Kevin Costner
# 64  1991            Jonathan Demme
# 65  1992            Clint Eastwood
# 66  1993          Steven Spielberg
# 67  1994           Robert Zemeckis
# 68  1995                Mel Gibson
# 69  1996         Anthony Minghella
# 70  1997             James Cameron
# 71  1998          Steven Spielberg
# 72  1999                Sam Mendes
# 73  2000         Steven Soderbergh
# 74  2001                Ron Howard
# 75  2002            Roman Polanski
# 76  2003             Peter Jackson
# 77  2004            Clint Eastwood
# 78  2005                   Ang Lee
# 79  2006           Martin Scorsese
# 80  2007             Coen Brothers
# 81  2008               Danny Boyle
# 82  2009           Kathryn Bigelow
# 83  2010                Tom Hooper
# 84  2011       Michel Hazanavicius
# 85  2012                   Ang Lee
# 86  2013            Alfonso Cuarón
# 87  2014     Alejandro G. Iñárritu
# 88  2015     Alejandro G. Iñárritu
# 89  2016           Damien Chazelle
# 90  2017        Guillermo del Toro
#
#                                              Film
# 0                                      7th Heaven
# 1                             Two Arabian Knights
# 2                                 The Divine Lady
# 3                  All Quiet on the Western Front
# 4                                          Skippy
# 5                                        Bad Girl
# 6                                       Cavalcade
# 7                           It Happened One Night
# 8                                    The Informer
# 9                          Mr. Deeds Goes to Town
# 10                                The Awful Truth
# 11                     You Can't Take It with You
# 12                             Gone with the Wind
# 13                            The Grapes of Wrath
# 14                        How Green Was My Valley
# 15                                   Mrs. Miniver
# 16                                     Casablanca
# 17                                   Going My Way
# 18                               The Lost Weekend
# 19                    The Best Years of Our Lives
# 20                          Gentleman's Agreement
# 21               The Treasure of the Sierra Madre
# 22                        A Letter to Three Wives
# 23                                  All About Eve
# 24                             A Place in the Sun
# 25                                  The Quiet Man
# 26                          From Here to Eternity
# 27                              On the Waterfront
# 28                                          Marty
# 29                                          Giant
# ..                                            ...
# 61                                       Rain Man
# 62                     Born on the Fourth of July
# 63                             Dances with Wolves
# 64                       The Silence of the Lambs
# 65                                     Unforgiven
# 66                               Schindler's List
# 67                                   Forrest Gump
# 68                                     Braveheart
# 69                            The English Patient
# 70                                        Titanic
# 71                            Saving Private Ryan
# 72                                American Beauty
# 73                                        Traffic
# 74                               A Beautiful Mind
# 75                                    The Pianist
# 76  The Lord of the Rings: The Return of the King
# 77                            Million Dollar Baby
# 78                             Brokeback Mountain
# 79                                   The Departed
# 80                         No Country for Old Men
# 81                            Slumdog Millionaire
# 82                                The Hurt Locker
# 83                              The King's Speech
# 84                                     The Artist
# 85                                     Life of Pi
# 86                                        Gravity
# 87                                        Birdman
# 88                                   The Revenant
# 89                                     La La Land
# 90                             The Shape of Water
#
# [91 rows x 3 columns]

# %%
# Page 3- Best Actor
data = loadPage("https://en.wikipedia.org/wiki/Academy_Award_for_Best_Actor")
tables = data.findAll("table", class_= "wikitable sortable")

# %%
# Here we extract each actor and film
films =[]
actors = []
for row in tables[0].findAll("tr"):
    cells = row.findAll("td", style="background:#FAEB86;")    
    # Index variable to keep track of the cell we are in
    index = 0
    for c in cells:
        # Get all the links within each cell
        links = c.findAll("a")
        for l in links:
            # If link has the attribute 'title' then we want it
            if(l.has_attr('title')):
                # If it is the first cell then get the text and add it to the list of actors
                if(index == 0): 
                    actor = l.find(text=True).encode('utf-8').strip()
                    actors.append(actor)
                # If it is the third cell then get the text and add it to the list of films
                elif(index == 2): 
                    film = l.find(text=True).encode('utf-8').strip()
                    films.append(film)
        # increment index
        index = index+1

# %%
# Here we extract the years
years = []
for row in tables[0].findAll("th", scope="row"):
    cells = row.findAll('a')     
    if(len(cells[0].find(text=True)) == 7):
        year = cells[0].find(text=True)[0:2] + cells[0].find(text=True)[5:7]
    elif(len(cells[1].find(text=True)) == 4):       
        if (cells[1].find(text=True).isnumeric()):
            year = cells[1].find(text=True)  
    elif(len(cells[1].find(text=True)) == 2):
        if (cells[1].find(text=True).isnumeric()):
            year = cells[0].find(text=True)[0:2] + cells[1].find(text=True)
    else:
        year = cells[0].find(text=True)[0:4]
    years.append(year)

# %%
# Check the length of each list. They are not the same. There are two reasons for this.
# 1. In the 1st Oscars the actor won awards for two films
# 2. In 1932 there was a tie for 1st place
print(len(films))
print(len(actors))
print(len(years))
# Out:
# 92
# 91
# 90

# %%
# To amend this lets insert the actor at position 0 into position 1 and insert the appropriate years at position 1 and 6 of years
actors.insert(1, actors[0])
years.insert(1, years[0])
years.insert(6, years[5])

# %%
# Now they are all the same length
print(len(films))
print(len(actors))
print(len(years))
# Out:
# 92
# 92
# 92

# %%
# Create a data frame for storing the lists
df_actors = pd.DataFrame()
df_actors["Year"] = pd.to_numeric(years, errors='coerce')
df_actors["Actor"] = actors
df_actors["Film"] = films
# Print the data frame and look at years 1928 and 1932
df_actors
# Out:
#     Year                   Actor                            Film
# 0   1928           Emil Jannings                The Last Command
# 1   1928           Emil Jannings            The Way of All Flesh
# 2   1929           Warner Baxter                  In Old Arizona
# 3   1930           George Arliss                        Disraeli
# 4   1931        Lionel Barrymore                     A Free Soul
# 5   1932           Wallace Beery                       The Champ
# 6   1932           Fredric March         Dr. Jekyll and Mr. Hyde
# 7   1933        Charles Laughton  The Private Life of Henry VIII
# 8   1934             Clark Gable           It Happened One Night
# 9   1935         Victor McLaglen                    The Informer
# 10  1936               Paul Muni      The Story of Louis Pasteur
# 11  1937           Spencer Tracy             Captains Courageous
# 12  1938           Spencer Tracy                       Boys Town
# 13  1939            Robert Donat              Goodbye, Mr. Chips
# 14  1940           James Stewart          The Philadelphia Story
# 15  1941             Gary Cooper                   Sergeant York
# 16  1942            James Cagney             Yankee Doodle Dandy
# 17  1943              Paul Lukas              Watch on the Rhine
# 18  1944             Bing Crosby                    Going My Way
# 19  1945             Ray Milland                The Lost Weekend
# 20  1946           Fredric March     The Best Years of Our Lives
# 21  1947           Ronald Colman                   A Double Life
# 22  1948        Laurence Olivier                          Hamlet
# 23  1949      Broderick Crawford              All the King's Men
# 24  1950             José Ferrer              Cyrano de Bergerac
# 25  1951         Humphrey Bogart               The African Queen
# 26  1952             Gary Cooper                       High Noon
# 27  1953          William Holden                       Stalag 17
# 28  1954           Marlon Brando               On the Waterfront
# 29  1955         Ernest Borgnine                           Marty
# ..   ...                     ...                             ...
# 62  1988          Dustin Hoffman                        Rain Man
# 63  1989        Daniel Day-Lewis                    My Left Foot
# 64  1990            Jeremy Irons             Reversal of Fortune
# 65  1991         Anthony Hopkins        The Silence of the Lambs
# 66  1992               Al Pacino                Scent of a Woman
# 67  1993               Tom Hanks                    Philadelphia
# 68  1994               Tom Hanks                    Forrest Gump
# 69  1995            Nicolas Cage               Leaving Las Vegas
# 70  1996           Geoffrey Rush                           Shine
# 71  1997          Jack Nicholson              As Good as It Gets
# 72  1998         Roberto Benigni               Life Is Beautiful
# 73  1999            Kevin Spacey                 American Beauty
# 74  2000           Russell Crowe                       Gladiator
# 75  2001       Denzel Washington                    Training Day
# 76  2002            Adrien Brody                     The Pianist
# 77  2003               Sean Penn                    Mystic River
# 78  2004              Jamie Foxx                             Ray
# 79  2005  Philip Seymour Hoffman                          Capote
# 80  2006         Forest Whitaker       The Last King of Scotland
# 81  2007        Daniel Day-Lewis             There Will Be Blood
# 82  2008               Sean Penn                            Milk
# 83  2009            Jeff Bridges                     Crazy Heart
# 84  2010             Colin Firth               The King's Speech
# 85  2011           Jean Dujardin                      The Artist
# 86  2012        Daniel Day-Lewis                         Lincoln
# 87  2013     Matthew McConaughey              Dallas Buyers Club
# 88  2014          Eddie Redmayne        The Theory of Everything
# 89  2015       Leonardo DiCaprio                    The Revenant
# 90  2016           Casey Affleck           Manchester by the Sea
# 91  2017             Gary Oldman                    Darkest Hour
#
# [92 rows x 3 columns]

# %%
# Page 4- Best Actress
data = loadPage("https://en.wikipedia.org/wiki/Academy_Award_for_Best_Actress")
tables = data.findAll("table", class_= "wikitable sortable")

# %%
# Here we extract each actress and film
films =[]
actresses = []
for row in tables[0].findAll("tr"):
    cells = row.findAll("td", style="background:#FAEB86;")   
    index = 0
    for c in cells:
        links = c.findAll("a")
        for l in links:
            if(l.has_attr('title')):
                if(index == 0): 
                    actress = l.find(text=True).encode('utf-8').strip()
                    actresses.append(actress)
                elif(index == 2): 
                    movie = l.find(text=True).encode('utf-8').strip()
                    films.append(movie)
        index = index+1

# %%
# Here we extract each year
years = []
for row in tables[0].findAll("th", scope="row"):
    cells = row.findAll('a')     
    if(len(cells[0].find(text=True)) == 7):
        year = cells[0].find(text=True)[0:2] + cells[0].find(text=True)[5:7]
    elif(len(cells[1].find(text=True)) == 4):       
        if (cells[1].find(text=True).isnumeric()):
            year = cells[1].find(text=True)  
    elif(len(cells[1].find(text=True)) == 2):
        if (cells[1].find(text=True).isnumeric()):
            year = cells[0].find(text=True)[0:2] + cells[1].find(text=True)
    else:
        year = cells[0].find(text=True)[0:4] 
    years.append(year)

# %%
# Check the length of each list. They are not the same. There are two reasons for this.
# 1. In the 1st Oscars the actress won awards for three films
# 2. In 1968 there was a tie for 1st place
print(len(actresses))
print(len(films))
print(len(years))
# Out:
# 91
# 93
# 90

# %%
# Lets amend this by inserting the actress at the position 0 to position 1 and 2. Do the same for the years
# Also insert the year at position 40 into position 41
actresses.insert(1, actresses[0])
actresses.insert(2, actresses[1])
years.insert(41, years[40])
years.insert(1, years[0])
years.insert(2, years[1])

# %%
# Now they are all the same length
print(len(actresses))
print(len(films))
print(len(years))
# Out:
# 93
# 93
# 93

# %%
# Create a data frame for storing the lists
df_actresses = pd.DataFrame()
df_actresses["Year"] = pd.to_numeric(years, errors='coerce')
df_actresses["Actress"] = actresses
df_actresses["Film"] = films
# Print the dataframe and look at the first three indexes which have the same year and actress but different films
df_actresses
# Out:
#     Year              Actress                                       Film
# 0   1928         Janet Gaynor                                 7th Heaven
# 1   1928         Janet Gaynor                               Street Angel
# 2   1928         Janet Gaynor              Sunrise: A Song of Two Humans
# 3   1929        Mary Pickford                                   Coquette
# 4   1930        Norma Shearer                               The Divorcee
# 5   1931       Marie Dressler                               Min and Bill
# 6   1932          Helen Hayes                 The Sin of Madelon Claudet
# 7   1933    Katharine Hepburn                              Morning Glory
# 8   1934    Claudette Colbert                      It Happened One Night
# 9   1935          Bette Davis                                  Dangerous
# 10  1936         Luise Rainer                         The Great Ziegfeld
# 11  1937         Luise Rainer                             The Good Earth
# 12  1938          Bette Davis                                    Jezebel
# 13  1939         Vivien Leigh                         Gone with the Wind
# 14  1940        Ginger Rogers                                Kitty Foyle
# 15  1941        Joan Fontaine                                  Suspicion
# 16  1942         Greer Garson                               Mrs. Miniver
# 17  1943       Jennifer Jones                     The Song of Bernadette
# 18  1944       Ingrid Bergman                                   Gaslight
# 19  1945        Joan Crawford                             Mildred Pierce
# 20  1946  Olivia de Havilland                            To Each His Own
# 21  1947        Loretta Young                      The Farmer's Daughter
# 22  1948           Jane Wyman                             Johnny Belinda
# 23  1949  Olivia de Havilland                                The Heiress
# 24  1950        Judy Holliday                             Born Yesterday
# 25  1951         Vivien Leigh                   A Streetcar Named Desire
# 26  1952        Shirley Booth                    Come Back, Little Sheba
# 27  1953       Audrey Hepburn                              Roman Holiday
# 28  1954          Grace Kelly                           The Country Girl
# 29  1955         Anna Magnani                            The Rose Tattoo
# ..   ...                  ...                                        ...
# 63  1988         Jodie Foster                                The Accused
# 64  1989        Jessica Tandy                         Driving Miss Daisy
# 65  1990          Kathy Bates                                     Misery
# 66  1991         Jodie Foster                   The Silence of the Lambs
# 67  1992        Emma Thompson                                Howards End
# 68  1993         Holly Hunter                                  The Piano
# 69  1994        Jessica Lange                                   Blue Sky
# 70  1995       Susan Sarandon                           Dead Man Walking
# 71  1996    Frances McDormand                                      Fargo
# 72  1997           Helen Hunt                         As Good as It Gets
# 73  1998      Gwyneth Paltrow                        Shakespeare in Love
# 74  1999         Hilary Swank                             Boys Don't Cry
# 75  2000        Julia Roberts                            Erin Brockovich
# 76  2001          Halle Berry                             Monster's Ball
# 77  2002        Nicole Kidman                                  The Hours
# 78  2003      Charlize Theron                                    Monster
# 79  2004         Hilary Swank                        Million Dollar Baby
# 80  2005    Reese Witherspoon                              Walk the Line
# 81  2006         Helen Mirren                                  The Queen
# 82  2007     Marion Cotillard                             La Vie en Rose
# 83  2008         Kate Winslet                                 The Reader
# 84  2009       Sandra Bullock                             The Blind Side
# 85  2010      Natalie Portman                                 Black Swan
# 86  2011         Meryl Streep                              The Iron Lady
# 87  2012    Jennifer Lawrence                    Silver Linings Playbook
# 88  2013       Cate Blanchett                               Blue Jasmine
# 89  2014       Julianne Moore                                Still Alice
# 90  2015          Brie Larson                                       Room
# 91  2016           Emma Stone                                 La La Land
# 92  2017    Frances McDormand  Three Billboards Outside Ebbing, Missouri
#
# [93 rows x 3 columns]

# %%
# Now check the year 1968 and see two actresses and films
df_actresses.loc[df_actresses['Year'] == 1968]
# Out:
#     Year            Actress                Film
# 42  1968  Katharine Hepburn  The Lion in Winter
# 43  1968   Barbra Streisand          Funny Girl

# %%
# Page 5 - Best Supporting Actor
data = loadPage("https://en.wikipedia.org/wiki/Academy_Award_for_Best_Supporting_Actor")
tables = data.findAll("table", class_= "wikitable sortable")

# %%
# Here we extract each actor and film
films =[]
actors = []
for row in tables[0].findAll("tr"):
    cells = row.findAll("td", style="background:#FAEB86")   
    index = 0
    for c in cells:
        links = c.findAll("a")
        for l in links:
            if(l.has_attr('title')):
                if(index == 0): 
                    actor = l.find(text=True).encode('utf-8').strip()
                    actors.append(actor)
                elif(index == 2): 
                    movie = l.find(text=True).encode('utf-8').strip()
                    films.append(movie)
        index = index+1

# %%
# Here we extract the years. Because these awards started in 1936 all the years are in the correct format
years = []
for row in tables[0].findAll("th", scope="row"):
    cells = row.findAll('a') 
    if(len(cells) > 1):        
        year = cells[0].find(text=True)[0:4] 
        years.append(year)

# %%
# Check all lists are the same length, they are
print(len(actors))
print(len(films))
print(len(years))
# Out:
# 82
# 82
# 82

# %%
# Create a data frame for storing the lists
df_supActors = pd.DataFrame()
df_supActors["Year"] = pd.to_numeric(years, errors='coerce')
df_supActors["Actor"] = actors
df_supActors["Film"] = films
# Print data frame
df_supActors
# Out:
#     Year                Actor                                       Film
# 0   1936       Walter Brennan                            Come and Get It
# 1   1937   Joseph Schildkraut                     The Life of Emile Zola
# 2   1938       Walter Brennan                                   Kentucky
# 3   1939      Thomas Mitchell                                 Stagecoach
# 4   1940       Walter Brennan                              The Westerner
# 5   1941         Donald Crisp                    How Green Was My Valley
# 6   1942           Van Heflin                               Johnny Eager
# 7   1943       Charles Coburn                       The More the Merrier
# 8   1944     Barry Fitzgerald                               Going My Way
# 9   1945           James Dunn                   A Tree Grows in Brooklyn
# 10  1946       Harold Russell                The Best Years of Our Lives
# 11  1947         Edmund Gwenn                     Miracle on 34th Street
# 12  1948        Walter Huston           The Treasure of the Sierra Madre
# 13  1949          Dean Jagger                        Twelve O'Clock High
# 14  1950       George Sanders                              All About Eve
# 15  1951          Karl Malden                   A Streetcar Named Desire
# 16  1952        Anthony Quinn                               Viva Zapata!
# 17  1953        Frank Sinatra                      From Here to Eternity
# 18  1954       Edmond O'Brien                      The Barefoot Contessa
# 19  1955          Jack Lemmon                             Mister Roberts
# 20  1956        Anthony Quinn                              Lust for Life
# 21  1957          Red Buttons                                   Sayonara
# 22  1958            Burl Ives                            The Big Country
# 23  1959        Hugh Griffith                                    Ben-Hur
# 24  1960        Peter Ustinov                                  Spartacus
# 25  1961      George Chakiris                            West Side Story
# 26  1962            Ed Begley                        Sweet Bird of Youth
# 27  1963       Melvyn Douglas                                        Hud
# 28  1964        Peter Ustinov                                    Topkapi
# 29  1965        Martin Balsam                          A Thousand Clowns
# ..   ...                  ...                                        ...
# 52  1988          Kevin Kline                        A Fish Called Wanda
# 53  1989    Denzel Washington                                      Glory
# 54  1990            Joe Pesci                                 Goodfellas
# 55  1991         Jack Palance                              City Slickers
# 56  1992         Gene Hackman                                 Unforgiven
# 57  1993      Tommy Lee Jones                               The Fugitive
# 58  1994        Martin Landau                                    Ed Wood
# 59  1995         Kevin Spacey                         The Usual Suspects
# 60  1996     Cuba Gooding Jr.                              Jerry Maguire
# 61  1997       Robin Williams                          Good Will Hunting
# 62  1998         James Coburn                                 Affliction
# 63  1999        Michael Caine                      The Cider House Rules
# 64  2000     Benicio del Toro                                    Traffic
# 65  2001        Jim Broadbent                                       Iris
# 66  2002         Chris Cooper                                Adaptation.
# 67  2003          Tim Robbins                               Mystic River
# 68  2004       Morgan Freeman                        Million Dollar Baby
# 69  2005       George Clooney                                    Syriana
# 70  2006           Alan Arkin                       Little Miss Sunshine
# 71  2007        Javier Bardem                     No Country for Old Men
# 72  2008         Heath Ledger                            The Dark Knight
# 73  2009      Christoph Waltz                       Inglourious Basterds
# 74  2010       Christian Bale                                The Fighter
# 75  2011  Christopher Plummer                                  Beginners
# 76  2012      Christoph Waltz                           Django Unchained
# 77  2013           Jared Leto                         Dallas Buyers Club
# 78  2014        J. K. Simmons                                   Whiplash
# 79  2015         Mark Rylance                            Bridge of Spies
# 80  2016       Mahershala Ali                                  Moonlight
# 81  2017         Sam Rockwell  Three Billboards Outside Ebbing, Missouri
#
# [82 rows x 3 columns]

# %%
# Page 6 - Best Supporting Actress
data = loadPage("https://en.wikipedia.org/wiki/Academy_Award_for_Best_Supporting_Actress")
tables = data.findAll("table", class_= "wikitable sortable")

# %%
# Here we extract each actress and film
films =[]
actresses = []
for row in tables[0].findAll("tr"):
    cells = row.findAll("td", style="background:#FAEB86;")   
    index = 0
    for c in cells:
        links = c.findAll("a")
        for l in links:
            if(l.has_attr('title')):
                if(index == 0): 
                    actress = l.find(text=True).encode('utf-8').strip()
                    actresses.append(actress)
                elif(index == 2): 
                    movie = l.find(text=True).encode('utf-8').strip()
                    films.append(movie)
        index = index+1

# %%
# Here we extract the years. Because these awards started in 1936 all the years are in the correct format
years = []
for row in tables[0].findAll("th", scope="row"):
    cells = row.findAll('a')  
    if(len(cells) > 1):
        year = cells[0].find(text=True)
        years.append(year)

# %%
# Check all the lists are the same length, they are
print(len(actresses))
print(len(films))
print(len(years))
# Out:
# 82
# 82
# 82

# %%
# Create a data frame for storing the lists
df_supActresses = pd.DataFrame()
df_supActresses["Year"] = pd.to_numeric(years, errors='coerce')
df_supActresses["Actress"] = actresses
df_supActresses["Film"] = films
# Print data frame
df_supActresses
# Out:
#     Year               Actress                       Film
# 0   1936      Gale Sondergaard            Anthony Adverse
# 1   1937           Alice Brady             In Old Chicago
# 2   1938           Fay Bainter                    Jezebel
# 3   1939       Hattie McDaniel         Gone with the Wind
# 4   1940          Jane Darwell        The Grapes of Wrath
# 5   1941            Mary Astor              The Great Lie
# 6   1942         Teresa Wright               Mrs. Miniver
# 7   1943        Katina Paxinou    For Whom the Bell Tolls
# 8   1944       Ethel Barrymore  None but the Lonely Heart
# 9   1945           Anne Revere            National Velvet
# 10  1946           Anne Baxter           The Razor's Edge
# 11  1947          Celeste Holm      Gentleman's Agreement
# 12  1948         Claire Trevor                  Key Largo
# 13  1949  Mercedes McCambridge         All the King's Men
# 14  1950        Josephine Hull                     Harvey
# 15  1951            Kim Hunter   A Streetcar Named Desire
# 16  1952        Gloria Grahame  The Bad and the Beautiful
# 17  1953            Donna Reed      From Here to Eternity
# 18  1954       Eva Marie Saint          On the Waterfront
# 19  1955          Jo Van Fleet               East of Eden
# 20  1956        Dorothy Malone        Written on the Wind
# 21  1957         Miyoshi Umeki                   Sayonara
# 22  1958          Wendy Hiller            Separate Tables
# 23  1959       Shelley Winters    The Diary of Anne Frank
# 24  1960         Shirley Jones               Elmer Gantry
# 25  1961           Rita Moreno            West Side Story
# 26  1962            Patty Duke         The Miracle Worker
# 27  1963   Margaret Rutherford                The V.I.P.s
# 28  1964          Lila Kedrova            Zorba the Greek
# 29  1965       Shelley Winters            A Patch of Blue
# ..   ...                   ...                        ...
# 52  1988           Geena Davis     The Accidental Tourist
# 53  1989        Brenda Fricker               My Left Foot
# 54  1990       Whoopi Goldberg                      Ghost
# 55  1991        Mercedes Ruehl            The Fisher King
# 56  1992          Marisa Tomei            My Cousin Vinny
# 57  1993           Anna Paquin                  The Piano
# 58  1994          Dianne Wiest      Bullets over Broadway
# 59  1995          Mira Sorvino           Mighty Aphrodite
# 60  1996      Juliette Binoche        The English Patient
# 61  1997          Kim Basinger          L.A. Confidential
# 62  1998            Judi Dench        Shakespeare in Love
# 63  1999        Angelina Jolie          Girl, Interrupted
# 64  2000     Marcia Gay Harden                    Pollock
# 65  2001     Jennifer Connelly           A Beautiful Mind
# 66  2002  Catherine Zeta-Jones                    Chicago
# 67  2003       Renée Zellweger              Cold Mountain
# 68  2004        Cate Blanchett                The Aviator
# 69  2005          Rachel Weisz      The Constant Gardener
# 70  2006       Jennifer Hudson                 Dreamgirls
# 71  2007         Tilda Swinton            Michael Clayton
# 72  2008         Penélope Cruz   Vicky Cristina Barcelona
# 73  2009              Mo'Nique                   Precious
# 74  2010           Melissa Leo                The Fighter
# 75  2011       Octavia Spencer                   The Help
# 76  2012         Anne Hathaway             Les Misérables
# 77  2013        Lupita Nyong'o           12 Years a Slave
# 78  2014     Patricia Arquette                    Boyhood
# 79  2015       Alicia Vikander            The Danish Girl
# 80  2016           Viola Davis                     Fences
# 81  2017        Allison Janney                   I, Tonya
#
# [82 rows x 3 columns]

# %%
# Print the number of rows in each data frame
print(df_picture.shape[0])
print(df_directors.shape[0])
print(df_actors.shape[0])
print(df_actresses.shape[0])
print(df_supActors.shape[0])
print(df_supActresses.shape[0])
# Out:
# 90
# 91
# 92
# 93
# 82
# 82

# %%
# Now all the data has been read into data frames, the next step is to connect to MYSQL and store it in the database
from sqlalchemy import create_engine    # for connecting to MySQL

# The following variables are used to connect to MySQL. Set your own values for user, password and db
user = ''
password = ''
host = 'localhost'
db = ''

# Connection object for MySQL
engine = create_engine("mysql+mysqldb://"+user+":"+password+"@"+host+"/"+db+"?charset=utf8")

# %%
# Insert the data from each data frame into tables. If the table already exists overwrite it
df_picture.to_sql('best_picture', con=engine, if_exists='replace', index_label='id')
df_directors.to_sql('best_director', con=engine, if_exists='replace', index_label='id')
df_actors.to_sql('best_actor', con=engine, if_exists='replace', index_label='id')
df_actresses.to_sql('best_actress', con=engine, if_exists='replace', index_label='id')
df_supActors.to_sql('best_supporting_actor', con=engine, if_exists='replace', index_label='id')
df_supActresses.to_sql('best_supporting_actress', con=engine, if_exists='replace', index_label='id')

# %%
# Show that the tables havebeen created
res = engine.execute("SHOW TABLES")
for x in res:
    print x
# Out:
# (u'best_actor',)
# (u'best_actress',)
# (u'best_director',)
# (u'best_picture',)
# (u'best_supporting_actor',)
# (u'best_supporting_actress',)
# (u'customers',)
# (u'products',)
# (u'users',)

# %%
# Now lets run some queries on the tables
# First return the number of row in each table
num_res = engine.execute("SELECT COUNT(*) FROM best_picture")
print("Best Picture number of rows")
for x in num_res:
    print x
num_res = engine.execute("SELECT COUNT(*) FROM best_director")
print("Best Director number of rows")
for x in num_res:
    print x
num_res = engine.execute("SELECT COUNT(*) FROM best_actor")
print("Best Actor number of rows")
for x in num_res:
    print x
num_res = engine.execute("SELECT COUNT(*) FROM best_actress")
print("Best Actress number of rows")
for x in num_res:
    print x
num_res = engine.execute("SELECT COUNT(*) FROM best_supporting_actor")
print("Best Supporting Actor number of rows")
for x in num_res:
    print x
num_res = engine.execute("SELECT COUNT(*) FROM best_supporting_actress")
print("Best Supporting Actress number of rows")
for x in num_res:
    print x
# Out:
# Best Picture number of rows
# (90L,)
# Best Director number of rows
# (91L,)
# Best Actor number of rows
# (92L,)
# Best Actress number of rows
# (93L,)
# Best Supporting Actor number of rows
# (82L,)
# Best Supporting Actress number of rows
# (82L,)

# %%
# Return all the rows from each table
table_pictures = engine.execute("SELECT * FROM best_picture")
for x in table_pictures:
    print x
# Out:
# (0L, 1928L, u'Wings', u'Paramount Famous Lasky')
# (1L, 1929L, u'The Broadway Melody', u'Metro-Goldwyn-Mayer')
# (2L, 1930L, u'All Quiet on the Western Front', u'Universal')
# (3L, 1931L, u'Cimarron', u'RKO Radio')
# (4L, 1932L, u'Grand Hotel', u'Metro-Goldwyn-Mayer')
# (5L, 1933L, u'Cavalcade', u'Fox')
# (6L, 1934L, u'It Happened One Night', u'Columbia')
# (7L, 1935L, u'Mutiny on the Bounty', u'Metro-Goldwyn-Mayer')
# (8L, 1936L, u'The Great Ziegfeld', u'Metro-Goldwyn-Mayer')
# (9L, 1937L, u'The Life of Emile Zola', u'Warner Bros.')
# (10L, 1938L, u"You Can't Take It with You", u'Columbia')
# (11L, 1939L, u'Gone with the Wind', u'Selznick International Pictures')
# (12L, 1940L, u'Rebecca', u'Selznick International Pictures')
# (13L, 1941L, u'How Green Was My Valley', u'20th Century-Fox')
# (14L, 1942L, u'Mrs. Miniver', u'Metro-Goldwyn-Mayer')
# (15L, 1943L, u'Casablanca', u'Warner Bros.')
# (16L, 1944L, u'Going My Way', u'Paramount')
# (17L, 1945L, u'The Lost Weekend', u'Paramount')
# (18L, 1946L, u'The Best Years of Our Lives', u'Samuel Goldwyn Productions')
# (19L, 1947L, u"Gentleman's Agreement", u'20th Century-Fox')
# (20L, 1948L, u'Hamlet', u'J. Arthur Rank-Two Cities Films')
# (21L, 1949L, u"All the King's Men", u'Robert Rossen Productions')
# (22L, 1950L, u'All About Eve', u'20th Century-Fox')
# (23L, 1951L, u'An American in Paris', u'Arthur Freed')
# (24L, 1952L, u'The Greatest Show on Earth', u'Cecil B. DeMille')
# (25L, 1953L, u'From Here to Eternity', u'Buddy Adler')
# (26L, 1954L, u'On the Waterfront', u'Sam Spiegel')
# (27L, 1955L, u'Marty', u'Harold Hecht')
# (28L, 1956L, u'Around the World in 80 Days', u'Michael Todd')
# (29L, 1957L, u'The Bridge on the River Kwai', u'Sam Spiegel')
# (30L, 1958L, u'Gigi', u'Arthur Freed')
# (31L, 1959L, u'Ben-Hur', u'Sam Zimbalist')
# (32L, 1960L, u'The Apartment', u'Billy Wilder')
# (33L, 1961L, u'West Side Story', u'Robert Wise')
# (34L, 1962L, u'Lawrence of Arabia', u'Sam Spiegel')
# (35L, 1963L, u'Tom Jones', u'Tony Richardson')
# (36L, 1964L, u'My Fair Lady', u'Jack L. Warner')
# (37L, 1965L, u'The Sound of Music', u'Robert Wise')
# (38L, 1966L, u'A Man for All Seasons', u'Fred Zinnemann')
# (39L, 1967L, u'In the Heat of the Night', u'Walter Mirisch')
# (40L, 1968L, u'Oliver!', u'John Woolf')
# (41L, 1969L, u'Midnight Cowboy', u'Jerome Hellman')
# (42L, 1970L, u'Patton', u'Frank McCarthy')
# (43L, 1971L, u'The French Connection', u"Philip D'Antoni")
# (44L, 1972L, u'The Godfather', u'Albert S. Ruddy')
# (45L, 1973L, u'The Sting', u'Tony Bill, Michael Phillips, and Julia Phillips')
# (46L, 1974L, u'The Godfather Part II', u'Francis Ford Coppola, Gray Frederickson, and Fred Roos')
# (47L, 1975L, u"One Flew Over the Cuckoo's Nest", u'Michael Douglas and Saul Zaentz')
# (48L, 1976L, u'Rocky', u'Irwin Winkler and Robert Chartoff')
# (49L, 1977L, u'Annie Hall', u'Charles H. Joffe')
# (50L, 1978L, u'The Deer Hunter', u'Barry Spikings, Michael Deeley, Michael Cimino, and John Peverall')
# (51L, 1979L, u'Kramer vs. Kramer', u'Stanley R. Jaffe')
# (52L, 1980L, u'Ordinary People', u'Ronald L. Schwary')
# (53L, 1981L, u'Chariots of Fire', u'David Puttnam')
# (54L, 1982L, u'Gandhi', u'Richard Attenborough')
# (55L, 1983L, u'Terms of Endearment', u'James L. Brooks')
# (56L, 1984L, u'Amadeus', u'Saul Zaentz')
# (57L, 1985L, u'Out of Africa', u'Sydney Pollack')
# (58L, 1986L, u'Platoon', u'Arnold Kopelson')
# (59L, 1987L, u'The Last Emperor', u'Jeremy Thomas')
# (60L, 1988L, u'Rain Man', u'Mark Johnson')
# (61L, 1989L, u'Driving Miss Daisy', u'Richard D. Zanuck and Lili Fini Zanuck')
# (62L, 1990L, u'Dances with Wolves', u'Jim Wilson and Kevin Costner')
# (63L, 1991L, u'The Silence of the Lambs', u'Edward Saxon, Kenneth Utt, and Ron Bozman')
# (64L, 1992L, u'Unforgiven', u'Clint Eastwood')
# (65L, 1993L, u"Schindler's List", u'Steven Spielberg, Gerald R. Molen, and Branko Lustig')
# (66L, 1994L, u'Forrest Gump', u'Wendy Finerman, Steve Tisch, and Steve Starkey')
# (67L, 1995L, u'Braveheart', u'Mel Gibson, Alan Ladd Jr., and Bruce Davey')
# (68L, 1996L, u'The English Patient', u'Saul Zaentz')
# (69L, 1997L, u'Titanic', u'James Cameron and Jon Landau')
# (70L, 1998L, u'Shakespeare in Love', u'David Parfitt, Donna Gigliotti, Harvey Weinstein, Edward Zwick, and Marc Norman')
# (71L, 1999L, u'American Beauty', u'Bruce Cohen and Dan Jinks')
# (72L, 2000L, u'Gladiator', u'Douglas Wick, David Franzoni, and Branko Lustig')
# (73L, 2001L, u'A Beautiful Mind', u'Brian Grazer and Ron Howard')
# (74L, 2002L, u'Chicago', u'Martin Richards')
# (75L, 2003L, u'The Lord of the Rings: The Return of the King', u'Barrie M. Osborne, Peter Jackson, and Fran Walsh')
# (76L, 2004L, u'Million Dollar Baby', u'Clint Eastwood, Albert S. Ruddy, and Tom Rosenberg')
# (77L, 2005L, u'Crash', u'Paul Haggis and Cathy Schulman')
# (78L, 2006L, u'The Departed', u'Graham King')
# (79L, 2007L, u'No Country for Old Men', u'Scott Rudin, Joel Coen, and Ethan Coen')
# (80L, 2008L, u'Slumdog Millionaire', u'Christian Colson')
# (81L, 2009L, u'The Hurt Locker', u'Kathryn Bigelow, Mark Boal, Nicolas Chartier, and Greg Shapiro')
# (82L, 2010L, u"The King's Speech", u'Iain Canning, Emile Sherman, and Gareth Unwin')
# (83L, 2011L, u'The Artist', u'Thomas Langmann')
# (84L, 2012L, u'Argo', u'Grant Heslov, Ben Affleck, and George Clooney')
# (85L, 2013L, u'12 Years a Slave', u'Brad Pitt, Dede Gardner, Jeremy Kleiner, Steve McQueen, and Anthony Katagas')
# (86L, 2014L, u'Birdman or (The Unexpected Virtue of Ignorance)', u'Alejandro G. I\xf1\xe1rritu, John Lesher, and James W. Skotchdopole')
# (87L, 2015L, u'Spotlight', u'Blye Pagon Faust, Steve Golin, Nicole Rocklin, and Michael Sugar')
# (88L, 2016L, u'Moonlight', u'Adele Romanski, Dede Gardner, and Jeremy Kleiner')
# (89L, 2017L, u'The Shape of Water', u'Guillermo del Toro and J. Miles Dale')

# %%
table_directors = engine.execute("SELECT * FROM best_director")
for x in table_directors:
    print x
# Out:
# (0L, 1928L, u'Frank Borzage (Dramatic)', u'7th Heaven')
# (1L, 1928L, u'Lewis Milestone (Comedy)', u'Two Arabian Knights')
# (2L, 1929L, u'Frank Lloyd', u'The Divine Lady')
# (3L, 1930L, u'Lewis Milestone', u'All Quiet on the Western Front')
# (4L, 1931L, u'Norman Taurog', u'Skippy')
# (5L, 1932L, u'Frank Borzage', u'Bad Girl')
# (6L, 1933L, u'Frank Lloyd', u'Cavalcade')
# (7L, 1934L, u'Frank Capra', u'It Happened One Night')
# (8L, 1935L, u'John Ford', u'The Informer')
# (9L, 1936L, u'Frank Capra', u'Mr. Deeds Goes to Town')
# (10L, 1937L, u'Leo McCarey', u'The Awful Truth')
# (11L, 1938L, u'Frank Capra', u"You Can't Take It with You")
# (12L, 1939L, u'Victor Fleming', u'Gone with the Wind')
# (13L, 1940L, u'John Ford', u'The Grapes of Wrath')
# (14L, 1941L, u'John Ford', u'How Green Was My Valley')
# (15L, 1942L, u'William Wyler', u'Mrs. Miniver')
# (16L, 1943L, u'Michael Curtiz', u'Casablanca')
# (17L, 1944L, u'Leo McCarey', u'Going My Way')
# (18L, 1945L, u'Billy Wilder', u'The Lost Weekend')
# (19L, 1946L, u'William Wyler', u'The Best Years of Our Lives')
# (20L, 1947L, u'Elia Kazan', u"Gentleman's Agreement")
# (21L, 1948L, u'John Huston', u'The Treasure of the Sierra Madre')
# (22L, 1949L, u'Joseph L. Mankiewicz', u'A Letter to Three Wives')
# (23L, 1950L, u'Joseph L. Mankiewicz', u'All About Eve')
# (24L, 1951L, u'George Stevens', u'A Place in the Sun')
# (25L, 1952L, u'John Ford', u'The Quiet Man')
# (26L, 1953L, u'Fred Zinnemann', u'From Here to Eternity')
# (27L, 1954L, u'Elia Kazan', u'On the Waterfront')
# (28L, 1955L, u'Delbert Mann', u'Marty')
# (29L, 1956L, u'George Stevens', u'Giant')
# (30L, 1957L, u'David Lean', u'The Bridge on the River Kwai')
# (31L, 1958L, u'Vincente Minnelli', u'Gigi')
# (32L, 1959L, u'William Wyler', u'Ben-Hur')
# (33L, 1960L, u'Billy Wilder', u'The Apartment')
# (34L, 1961L, u'Robert Wise & Jerome Robbins', u'West Side Story')
# (35L, 1962L, u'David Lean', u'Lawrence of Arabia')
# (36L, 1963L, u'Tony Richardson', u'Tom Jones')
# (37L, 1964L, u'George Cukor', u'My Fair Lady')
# (38L, 1965L, u'Robert Wise', u'The Sound of Music')
# (39L, 1966L, u'Fred Zinnemann', u'A Man for All Seasons')
# (40L, 1967L, u'Mike Nichols', u'The Graduate')
# (41L, 1968L, u'Carol Reed', u'Oliver!')
# (42L, 1969L, u'John Schlesinger', u'Midnight Cowboy')
# (43L, 1970L, u'Franklin J. Schaffner', u'Patton')
# (44L, 1971L, u'William Friedkin', u'The French Connection')
# (45L, 1972L, u'Bob Fosse', u'Cabaret')
# (46L, 1973L, u'George Roy Hill', u'The Sting')
# (47L, 1974L, u'Francis Ford Coppola', u'The Godfather Part II')
# (48L, 1975L, u'Milo\u0161 Forman', u"One Flew Over the Cuckoo's Nest")
# (49L, 1976L, u'John G. Avildsen', u'Rocky')
# (50L, 1977L, u'Woody Allen', u'Annie Hall')
# (51L, 1978L, u'Michael Cimino', u'The Deer Hunter')
# (52L, 1979L, u'Robert Benton', u'Kramer vs. Kramer')
# (53L, 1980L, u'Robert Redford', u'Ordinary People')
# (54L, 1981L, u'Warren Beatty', u'Reds')
# (55L, 1982L, u'Richard Attenborough', u'Gandhi')
# (56L, 1983L, u'James L. Brooks', u'Terms of Endearment')
# (57L, 1984L, u'Milo\u0161 Forman', u'Amadeus')
# (58L, 1985L, u'Sydney Pollack', u'Out of Africa')
# (59L, 1986L, u'Oliver Stone', u'Platoon')
# (60L, 1987L, u'Bernardo Bertolucci', u'The Last Emperor')
# (61L, 1988L, u'Barry Levinson', u'Rain Man')
# (62L, 1989L, u'Oliver Stone', u'Born on the Fourth of July')
# (63L, 1990L, u'Kevin Costner', u'Dances with Wolves')
# (64L, 1991L, u'Jonathan Demme', u'The Silence of the Lambs')
# (65L, 1992L, u'Clint Eastwood', u'Unforgiven')
# (66L, 1993L, u'Steven Spielberg', u"Schindler's List")
# (67L, 1994L, u'Robert Zemeckis', u'Forrest Gump')
# (68L, 1995L, u'Mel Gibson', u'Braveheart')
# (69L, 1996L, u'Anthony Minghella', u'The English Patient')
# (70L, 1997L, u'James Cameron', u'Titanic')
# (71L, 1998L, u'Steven Spielberg', u'Saving Private Ryan')
# (72L, 1999L, u'Sam Mendes', u'American Beauty')
# (73L, 2000L, u'Steven Soderbergh', u'Traffic')
# (74L, 2001L, u'Ron Howard', u'A Beautiful Mind')
# (75L, 2002L, u'Roman Polanski', u'The Pianist')
# (76L, 2003L, u'Peter Jackson', u'The Lord of the Rings: The Return of the King')
# (77L, 2004L, u'Clint Eastwood', u'Million Dollar Baby')
# (78L, 2005L, u'Ang Lee', u'Brokeback Mountain')
# (79L, 2006L, u'Martin Scorsese', u'The Departed')
# (80L, 2007L, u'Coen Brothers', u'No Country for Old Men')
# (81L, 2008L, u'Danny Boyle', u'Slumdog Millionaire')
# (82L, 2009L, u'Kathryn Bigelow', u'The Hurt Locker')
# (83L, 2010L, u'Tom Hooper', u"The King's Speech")
# (84L, 2011L, u'Michel Hazanavicius', u'The Artist')
# (85L, 2012L, u'Ang Lee', u'Life of Pi')
# (86L, 2013L, u'Alfonso Cuar\xf3n', u'Gravity')
# (87L, 2014L, u'Alejandro G. I\xf1\xe1rritu', u'Birdman')
# (88L, 2015L, u'Alejandro G. I\xf1\xe1rritu', u'The Revenant')
# (89L, 2016L, u'Damien Chazelle', u'La La Land')
# (90L, 2017L, u'Guillermo del Toro', u'The Shape of Water')

# %%
table_actors = engine.execute("SELECT * FROM best_actor")
for x in table_actors:
    print x
# Out:
# (0L, 1928L, u'Emil Jannings', u'The Last Command')
# (1L, 1928L, u'Emil Jannings', u'The Way of All Flesh')
# (2L, 1929L, u'Warner Baxter', u'In Old Arizona')
# (3L, 1930L, u'George Arliss', u'Disraeli')
# (4L, 1931L, u'Lionel Barrymore', u'A Free Soul')
# (5L, 1932L, u'Wallace Beery', u'The Champ')
# (6L, 1932L, u'Fredric March', u'Dr. Jekyll and Mr. Hyde')
# (7L, 1933L, u'Charles Laughton', u'The Private Life of Henry VIII')
# (8L, 1934L, u'Clark Gable', u'It Happened One Night')
# (9L, 1935L, u'Victor McLaglen', u'The Informer')
# (10L, 1936L, u'Paul Muni', u'The Story of Louis Pasteur')
# (11L, 1937L, u'Spencer Tracy', u'Captains Courageous')
# (12L, 1938L, u'Spencer Tracy', u'Boys Town')
# (13L, 1939L, u'Robert Donat', u'Goodbye, Mr. Chips')
# (14L, 1940L, u'James Stewart', u'The Philadelphia Story')
# (15L, 1941L, u'Gary Cooper', u'Sergeant York')
# (16L, 1942L, u'James Cagney', u'Yankee Doodle Dandy')
# (17L, 1943L, u'Paul Lukas', u'Watch on the Rhine')
# (18L, 1944L, u'Bing Crosby', u'Going My Way')
# (19L, 1945L, u'Ray Milland', u'The Lost Weekend')
# (20L, 1946L, u'Fredric March', u'The Best Years of Our Lives')
# (21L, 1947L, u'Ronald Colman', u'A Double Life')
# (22L, 1948L, u'Laurence Olivier', u'Hamlet')
# (23L, 1949L, u'Broderick Crawford', u"All the King's Men")
# (24L, 1950L, u'Jos\xe9 Ferrer', u'Cyrano de Bergerac')
# (25L, 1951L, u'Humphrey Bogart', u'The African Queen')
# (26L, 1952L, u'Gary Cooper', u'High Noon')
# (27L, 1953L, u'William Holden', u'Stalag 17')
# (28L, 1954L, u'Marlon Brando', u'On the Waterfront')
# (29L, 1955L, u'Ernest Borgnine', u'Marty')
# (30L, 1956L, u'Yul Brynner', u'The King and I')
# (31L, 1957L, u'Alec Guinness', u'The Bridge on the River Kwai')
# (32L, 1958L, u'David Niven', u'Separate Tables')
# (33L, 1959L, u'Charlton Heston', u'Ben-Hur')
# (34L, 1960L, u'Burt Lancaster', u'Elmer Gantry')
# (35L, 1961L, u'Maximilian Schell', u'Judgment at Nuremberg')
# (36L, 1962L, u'Gregory Peck', u'To Kill a Mockingbird')
# (37L, 1963L, u'Sidney Poitier', u'Lilies of the Field')
# (38L, 1964L, u'Rex Harrison', u'My Fair Lady')
# (39L, 1965L, u'Lee Marvin', u'Cat Ballou')
# (40L, 1966L, u'Paul Scofield', u'A Man for All Seasons')
# (41L, 1967L, u'Rod Steiger', u'In the Heat of the Night')
# (42L, 1968L, u'Cliff Robertson', u'Charly')
# (43L, 1969L, u'John Wayne', u'True Grit')
# (44L, 1970L, u'George C. Scott', u'Patton')
# (45L, 1971L, u'Gene Hackman', u'The French Connection')
# (46L, 1972L, u'Marlon Brando', u'The Godfather')
# (47L, 1973L, u'Jack Lemmon', u'Save the Tiger')
# (48L, 1974L, u'Art Carney', u'Harry and Tonto')
# (49L, 1975L, u'Jack Nicholson', u"One Flew Over the Cuckoo's Nest")
# (50L, 1976L, u'Peter Finch', u'Network')
# (51L, 1977L, u'Richard Dreyfuss', u'The Goodbye Girl')
# (52L, 1978L, u'Jon Voight', u'Coming Home')
# (53L, 1979L, u'Dustin Hoffman', u'Kramer vs. Kramer')
# (54L, 1980L, u'Robert De Niro', u'Raging Bull')
# (55L, 1981L, u'Henry Fonda', u'On Golden Pond')
# (56L, 1982L, u'Ben Kingsley', u'Gandhi')
# (57L, 1983L, u'Robert Duvall', u'Tender Mercies')
# (58L, 1984L, u'F. Murray Abraham', u'Amadeus')
# (59L, 1985L, u'William Hurt', u'Kiss of the Spider Woman')
# (60L, 1986L, u'Paul Newman', u'The Color of Money')
# (61L, 1987L, u'Michael Douglas', u'Wall Street')
# (62L, 1988L, u'Dustin Hoffman', u'Rain Man')
# (63L, 1989L, u'Daniel Day-Lewis', u'My Left Foot')
# (64L, 1990L, u'Jeremy Irons', u'Reversal of Fortune')
# (65L, 1991L, u'Anthony Hopkins', u'The Silence of the Lambs')
# (66L, 1992L, u'Al Pacino', u'Scent of a Woman')
# (67L, 1993L, u'Tom Hanks', u'Philadelphia')
# (68L, 1994L, u'Tom Hanks', u'Forrest Gump')
# (69L, 1995L, u'Nicolas Cage', u'Leaving Las Vegas')
# (70L, 1996L, u'Geoffrey Rush', u'Shine')
# (71L, 1997L, u'Jack Nicholson', u'As Good as It Gets')
# (72L, 1998L, u'Roberto Benigni', u'Life Is Beautiful')
# (73L, 1999L, u'Kevin Spacey', u'American Beauty')
# (74L, 2000L, u'Russell Crowe', u'Gladiator')
# (75L, 2001L, u'Denzel Washington', u'Training Day')
# (76L, 2002L, u'Adrien Brody', u'The Pianist')
# (77L, 2003L, u'Sean Penn', u'Mystic River')
# (78L, 2004L, u'Jamie Foxx', u'Ray')
# (79L, 2005L, u'Philip Seymour Hoffman', u'Capote')
# (80L, 2006L, u'Forest Whitaker', u'The Last King of Scotland')
# (81L, 2007L, u'Daniel Day-Lewis', u'There Will Be Blood')
# (82L, 2008L, u'Sean Penn', u'Milk')
# (83L, 2009L, u'Jeff Bridges', u'Crazy Heart')
# (84L, 2010L, u'Colin Firth', u"The King's Speech")
# (85L, 2011L, u'Jean Dujardin', u'The Artist')
# (86L, 2012L, u'Daniel Day-Lewis', u'Lincoln')
# (87L, 2013L, u'Matthew McConaughey', u'Dallas Buyers Club')
# (88L, 2014L, u'Eddie Redmayne', u'The Theory of Everything')
# (89L, 2015L, u'Leonardo DiCaprio', u'The Revenant')
# (90L, 2016L, u'Casey Affleck', u'Manchester by the Sea')
# (91L, 2017L, u'Gary Oldman', u'Darkest Hour')

# %%
table_actresses = engine.execute("SELECT * FROM best_actress")
for x in table_actresses:
    print x
# Out:
# (0L, 1928L, u'Janet Gaynor', u'7th Heaven')
# (1L, 1928L, u'Janet Gaynor', u'Street Angel')
# (2L, 1928L, u'Janet Gaynor', u'Sunrise: A Song of Two Humans')
# (3L, 1929L, u'Mary Pickford', u'Coquette')
# (4L, 1930L, u'Norma Shearer', u'The Divorcee')
# (5L, 1931L, u'Marie Dressler', u'Min and Bill')
# (6L, 1932L, u'Helen Hayes', u'The Sin of Madelon Claudet')
# (7L, 1933L, u'Katharine Hepburn', u'Morning Glory')
# (8L, 1934L, u'Claudette Colbert', u'It Happened One Night')
# (9L, 1935L, u'Bette Davis', u'Dangerous')
# (10L, 1936L, u'Luise Rainer', u'The Great Ziegfeld')
# (11L, 1937L, u'Luise Rainer', u'The Good Earth')
# (12L, 1938L, u'Bette Davis', u'Jezebel')
# (13L, 1939L, u'Vivien Leigh', u'Gone with the Wind')
# (14L, 1940L, u'Ginger Rogers', u'Kitty Foyle')
# (15L, 1941L, u'Joan Fontaine', u'Suspicion')
# (16L, 1942L, u'Greer Garson', u'Mrs. Miniver')
# (17L, 1943L, u'Jennifer Jones', u'The Song of Bernadette')
# (18L, 1944L, u'Ingrid Bergman', u'Gaslight')
# (19L, 1945L, u'Joan Crawford', u'Mildred Pierce')
# (20L, 1946L, u'Olivia de Havilland', u'To Each His Own')
# (21L, 1947L, u'Loretta Young', u"The Farmer's Daughter")
# (22L, 1948L, u'Jane Wyman', u'Johnny Belinda')
# (23L, 1949L, u'Olivia de Havilland', u'The Heiress')
# (24L, 1950L, u'Judy Holliday', u'Born Yesterday')
# (25L, 1951L, u'Vivien Leigh', u'A Streetcar Named Desire')
# (26L, 1952L, u'Shirley Booth', u'Come Back, Little Sheba')
# (27L, 1953L, u'Audrey Hepburn', u'Roman Holiday')
# (28L, 1954L, u'Grace Kelly', u'The Country Girl')
# (29L, 1955L, u'Anna Magnani', u'The Rose Tattoo')
# (30L, 1956L, u'Ingrid Bergman', u'Anastasia')
# (31L, 1957L, u'Joanne Woodward', u'The Three Faces of Eve')
# (32L, 1958L, u'Susan Hayward', u'I Want to Live!')
# (33L, 1959L, u'Simone Signoret', u'Room at the Top')
# (34L, 1960L, u'Elizabeth Taylor', u'BUtterfield 8')
# (35L, 1961L, u'Sophia Loren', u'Two Women')
# (36L, 1962L, u'Anne Bancroft', u'The Miracle Worker')
# (37L, 1963L, u'Patricia Neal', u'Hud')
# (38L, 1964L, u'Julie Andrews', u'Mary Poppins')
# (39L, 1965L, u'Julie Christie', u'Darling')
# (40L, 1966L, u'Elizabeth Taylor', u"Who's Afraid of Virginia Woolf?")
# (41L, 1967L, u'Katharine Hepburn', u"Guess Who's Coming to Dinner")
# (42L, 1968L, u'Katharine Hepburn', u'The Lion in Winter')
# (43L, 1968L, u'Barbra Streisand', u'Funny Girl')
# (44L, 1969L, u'Maggie Smith', u'The Prime of Miss Jean Brodie')
# (45L, 1970L, u'Glenda Jackson', u'Women in Love')
# (46L, 1971L, u'Jane Fonda', u'Klute')
# (47L, 1972L, u'Liza Minnelli', u'Cabaret')
# (48L, 1973L, u'Glenda Jackson', u'A Touch of Class')
# (49L, 1974L, u'Ellen Burstyn', u"Alice Doesn't Live Here Anymore")
# (50L, 1975L, u'Louise Fletcher', u"One Flew Over the Cuckoo's Nest")
# (51L, 1976L, u'Faye Dunaway', u'Network')
# (52L, 1977L, u'Diane Keaton', u'Annie Hall')
# (53L, 1978L, u'Jane Fonda', u'Coming Home')
# (54L, 1979L, u'Sally Field', u'Norma Rae')
# (55L, 1980L, u'Sissy Spacek', u"Coal Miner's Daughter")
# (56L, 1981L, u'Katharine Hepburn', u'On Golden Pond')
# (57L, 1982L, u'Meryl Streep', u"Sophie's Choice")
# (58L, 1983L, u'Shirley MacLaine', u'Terms of Endearment')
# (59L, 1984L, u'Sally Field', u'Places in the Heart')
# (60L, 1985L, u'Geraldine Page', u'The Trip to Bountiful')
# (61L, 1986L, u'Marlee Matlin', u'Children of a Lesser God')
# (62L, 1987L, u'Cher', u'Moonstruck')
# (63L, 1988L, u'Jodie Foster', u'The Accused')
# (64L, 1989L, u'Jessica Tandy', u'Driving Miss Daisy')
# (65L, 1990L, u'Kathy Bates', u'Misery')
# (66L, 1991L, u'Jodie Foster', u'The Silence of the Lambs')
# (67L, 1992L, u'Emma Thompson', u'Howards End')
# (68L, 1993L, u'Holly Hunter', u'The Piano')
# (69L, 1994L, u'Jessica Lange', u'Blue Sky')
# (70L, 1995L, u'Susan Sarandon', u'Dead Man Walking')
# (71L, 1996L, u'Frances McDormand', u'Fargo')
# (72L, 1997L, u'Helen Hunt', u'As Good as It Gets')
# (73L, 1998L, u'Gwyneth Paltrow', u'Shakespeare in Love')
# (74L, 1999L, u'Hilary Swank', u"Boys Don't Cry")
# (75L, 2000L, u'Julia Roberts', u'Erin Brockovich')
# (76L, 2001L, u'Halle Berry', u"Monster's Ball")
# (77L, 2002L, u'Nicole Kidman', u'The Hours')
# (78L, 2003L, u'Charlize Theron', u'Monster')
# (79L, 2004L, u'Hilary Swank', u'Million Dollar Baby')
# (80L, 2005L, u'Reese Witherspoon', u'Walk the Line')
# (81L, 2006L, u'Helen Mirren', u'The Queen')
# (82L, 2007L, u'Marion Cotillard', u'La Vie en Rose')
# (83L, 2008L, u'Kate Winslet', u'The Reader')
# (84L, 2009L, u'Sandra Bullock', u'The Blind Side')
# (85L, 2010L, u'Natalie Portman', u'Black Swan')
# (86L, 2011L, u'Meryl Streep', u'The Iron Lady')
# (87L, 2012L, u'Jennifer Lawrence', u'Silver Linings Playbook')
# (88L, 2013L, u'Cate Blanchett', u'Blue Jasmine')
# (89L, 2014L, u'Julianne Moore', u'Still Alice')
# (90L, 2015L, u'Brie Larson', u'Room')
# (91L, 2016L, u'Emma Stone', u'La La Land')
# (92L, 2017L, u'Frances McDormand', u'Three Billboards Outside Ebbing, Missouri')

# %%
table_supActors = engine.execute("SELECT * FROM best_supporting_actor")
for x in table_supActors:
    print x
# Out:
# (0L, 1936L, u'Walter Brennan', u'Come and Get It')
# (1L, 1937L, u'Joseph Schildkraut', u'The Life of Emile Zola')
# (2L, 1938L, u'Walter Brennan', u'Kentucky')
# (3L, 1939L, u'Thomas Mitchell', u'Stagecoach')
# (4L, 1940L, u'Walter Brennan', u'The Westerner')
# (5L, 1941L, u'Donald Crisp', u'How Green Was My Valley')
# (6L, 1942L, u'Van Heflin', u'Johnny Eager')
# (7L, 1943L, u'Charles Coburn', u'The More the Merrier')
# (8L, 1944L, u'Barry Fitzgerald', u'Going My Way')
# (9L, 1945L, u'James Dunn', u'A Tree Grows in Brooklyn')
# (10L, 1946L, u'Harold Russell', u'The Best Years of Our Lives')
# (11L, 1947L, u'Edmund Gwenn', u'Miracle on 34th Street')
# (12L, 1948L, u'Walter Huston', u'The Treasure of the Sierra Madre')
# (13L, 1949L, u'Dean Jagger', u"Twelve O'Clock High")
# (14L, 1950L, u'George Sanders', u'All About Eve')
# (15L, 1951L, u'Karl Malden', u'A Streetcar Named Desire')
# (16L, 1952L, u'Anthony Quinn', u'Viva Zapata!')
# (17L, 1953L, u'Frank Sinatra', u'From Here to Eternity')
# (18L, 1954L, u"Edmond O'Brien", u'The Barefoot Contessa')
# (19L, 1955L, u'Jack Lemmon', u'Mister Roberts')
# (20L, 1956L, u'Anthony Quinn', u'Lust for Life')
# (21L, 1957L, u'Red Buttons', u'Sayonara')
# (22L, 1958L, u'Burl Ives', u'The Big Country')
# (23L, 1959L, u'Hugh Griffith', u'Ben-Hur')
# (24L, 1960L, u'Peter Ustinov', u'Spartacus')
# (25L, 1961L, u'George Chakiris', u'West Side Story')
# (26L, 1962L, u'Ed Begley', u'Sweet Bird of Youth')
# (27L, 1963L, u'Melvyn Douglas', u'Hud')
# (28L, 1964L, u'Peter Ustinov', u'Topkapi')
# (29L, 1965L, u'Martin Balsam', u'A Thousand Clowns')
# (30L, 1966L, u'Walter Matthau', u'The Fortune Cookie')
# (31L, 1967L, u'George Kennedy', u'Cool Hand Luke')
# (32L, 1968L, u'Jack Albertson', u'The Subject Was Roses')
# (33L, 1969L, u'Gig Young', u"They Shoot Horses, Don't They?")
# (34L, 1970L, u'John Mills', u"Ryan's Daughter")
# (35L, 1971L, u'Ben Johnson', u'The Last Picture Show')
# (36L, 1972L, u'Joel Grey', u'Cabaret')
# (37L, 1973L, u'John Houseman', u'The Paper Chase')
# (38L, 1974L, u'Robert De Niro', u'The Godfather Part II')
# (39L, 1975L, u'George Burns', u'The Sunshine Boys')
# (40L, 1976L, u'Jason Robards', u"All the President's Men")
# (41L, 1977L, u'Jason Robards', u'Julia')
# (42L, 1978L, u'Christopher Walken', u'The Deer Hunter')
# (43L, 1979L, u'Melvyn Douglas', u'Being There')
# (44L, 1980L, u'Timothy Hutton', u'Ordinary People')
# (45L, 1981L, u'John Gielgud', u'Arthur')
# (46L, 1982L, u'Louis Gossett Jr.', u'An Officer and a Gentleman')
# (47L, 1983L, u'Jack Nicholson', u'Terms of Endearment')
# (48L, 1984L, u'Haing S. Ngor', u'The Killing Fields')
# (49L, 1985L, u'Don Ameche', u'Cocoon')
# (50L, 1986L, u'Michael Caine', u'Hannah and Her Sisters')
# (51L, 1987L, u'Sean Connery', u'The Untouchables')
# (52L, 1988L, u'Kevin Kline', u'A Fish Called Wanda')
# (53L, 1989L, u'Denzel Washington', u'Glory')
# (54L, 1990L, u'Joe Pesci', u'Goodfellas')
# (55L, 1991L, u'Jack Palance', u'City Slickers')
# (56L, 1992L, u'Gene Hackman', u'Unforgiven')
# (57L, 1993L, u'Tommy Lee Jones', u'The Fugitive')
# (58L, 1994L, u'Martin Landau', u'Ed Wood')
# (59L, 1995L, u'Kevin Spacey', u'The Usual Suspects')
# (60L, 1996L, u'Cuba Gooding Jr.', u'Jerry Maguire')
# (61L, 1997L, u'Robin Williams', u'Good Will Hunting')
# (62L, 1998L, u'James Coburn', u'Affliction')
# (63L, 1999L, u'Michael Caine', u'The Cider House Rules')
# (64L, 2000L, u'Benicio del Toro', u'Traffic')
# (65L, 2001L, u'Jim Broadbent', u'Iris')
# (66L, 2002L, u'Chris Cooper', u'Adaptation.')
# (67L, 2003L, u'Tim Robbins', u'Mystic River')
# (68L, 2004L, u'Morgan Freeman', u'Million Dollar Baby')
# (69L, 2005L, u'George Clooney', u'Syriana')
# (70L, 2006L, u'Alan Arkin', u'Little Miss Sunshine')
# (71L, 2007L, u'Javier Bardem', u'No Country for Old Men')
# (72L, 2008L, u'Heath Ledger', u'The Dark Knight')
# (73L, 2009L, u'Christoph Waltz', u'Inglourious Basterds')
# (74L, 2010L, u'Christian Bale', u'The Fighter')
# (75L, 2011L, u'Christopher Plummer', u'Beginners')
# (76L, 2012L, u'Christoph Waltz', u'Django Unchained')
# (77L, 2013L, u'Jared Leto', u'Dallas Buyers Club')
# (78L, 2014L, u'J. K. Simmons', u'Whiplash')
# (79L, 2015L, u'Mark Rylance', u'Bridge of Spies')
# (80L, 2016L, u'Mahershala Ali', u'Moonlight')
# (81L, 2017L, u'Sam Rockwell', u'Three Billboards Outside Ebbing, Missouri')

# %%
table_supActresses = engine.execute("SELECT * FROM best_supporting_actress")
for x in table_supActresses:
    print x
# Out:
# (0L, 1936L, u'Gale Sondergaard', u'Anthony Adverse')
# (1L, 1937L, u'Alice Brady', u'In Old Chicago')
# (2L, 1938L, u'Fay Bainter', u'Jezebel')
# (3L, 1939L, u'Hattie McDaniel', u'Gone with the Wind')
# (4L, 1940L, u'Jane Darwell', u'The Grapes of Wrath')
# (5L, 1941L, u'Mary Astor', u'The Great Lie')
# (6L, 1942L, u'Teresa Wright', u'Mrs. Miniver')
# (7L, 1943L, u'Katina Paxinou', u'For Whom the Bell Tolls')
# (8L, 1944L, u'Ethel Barrymore', u'None but the Lonely Heart')
# (9L, 1945L, u'Anne Revere', u'National Velvet')
# (10L, 1946L, u'Anne Baxter', u"The Razor's Edge")
# (11L, 1947L, u'Celeste Holm', u"Gentleman's Agreement")
# (12L, 1948L, u'Claire Trevor', u'Key Largo')
# (13L, 1949L, u'Mercedes McCambridge', u"All the King's Men")
# (14L, 1950L, u'Josephine Hull', u'Harvey')
# (15L, 1951L, u'Kim Hunter', u'A Streetcar Named Desire')
# (16L, 1952L, u'Gloria Grahame', u'The Bad and the Beautiful')
# (17L, 1953L, u'Donna Reed', u'From Here to Eternity')
# (18L, 1954L, u'Eva Marie Saint', u'On the Waterfront')
# (19L, 1955L, u'Jo Van Fleet', u'East of Eden')
# (20L, 1956L, u'Dorothy Malone', u'Written on the Wind')
# (21L, 1957L, u'Miyoshi Umeki', u'Sayonara')
# (22L, 1958L, u'Wendy Hiller', u'Separate Tables')
# (23L, 1959L, u'Shelley Winters', u'The Diary of Anne Frank')
# (24L, 1960L, u'Shirley Jones', u'Elmer Gantry')
# (25L, 1961L, u'Rita Moreno', u'West Side Story')
# (26L, 1962L, u'Patty Duke', u'The Miracle Worker')
# (27L, 1963L, u'Margaret Rutherford', u'The V.I.P.s')
# (28L, 1964L, u'Lila Kedrova', u'Zorba the Greek')
# (29L, 1965L, u'Shelley Winters', u'A Patch of Blue')
# (30L, 1966L, u'Sandy Dennis', u"Who's Afraid of Virginia Woolf?")
# (31L, 1967L, u'Estelle Parsons', u'Bonnie and Clyde')
# (32L, 1968L, u'Ruth Gordon', u"Rosemary's Baby")
# (33L, 1969L, u'Goldie Hawn', u'Cactus Flower')
# (34L, 1970L, u'Helen Hayes', u'Airport')
# (35L, 1971L, u'Cloris Leachman', u'The Last Picture Show')
# (36L, 1972L, u'Eileen Heckart', u'Butterflies Are Free')
# (37L, 1973L, u"Tatum O'Neal", u'Paper Moon')
# (38L, 1974L, u'Ingrid Bergman', u'Murder on the Orient Express')
# (39L, 1975L, u'Lee Grant', u'Shampoo')
# (40L, 1976L, u'Beatrice Straight', u'Network')
# (41L, 1977L, u'Vanessa Redgrave', u'Julia')
# (42L, 1978L, u'Maggie Smith', u'California Suite')
# (43L, 1979L, u'Meryl Streep', u'Kramer vs. Kramer')
# (44L, 1980L, u'Mary Steenburgen', u'Melvin and Howard')
# (45L, 1981L, u'Maureen Stapleton', u'Reds')
# (46L, 1982L, u'Jessica Lange', u'Tootsie')
# (47L, 1983L, u'Linda Hunt', u'The Year of Living Dangerously')
# (48L, 1984L, u'Peggy Ashcroft', u'A Passage to India')
# (49L, 1985L, u'Anjelica Huston', u"Prizzi's Honor")
# (50L, 1986L, u'Dianne Wiest', u'Hannah and Her Sisters')
# (51L, 1987L, u'Olympia Dukakis', u'Moonstruck')
# (52L, 1988L, u'Geena Davis', u'The Accidental Tourist')
# (53L, 1989L, u'Brenda Fricker', u'My Left Foot')
# (54L, 1990L, u'Whoopi Goldberg', u'Ghost')
# (55L, 1991L, u'Mercedes Ruehl', u'The Fisher King')
# (56L, 1992L, u'Marisa Tomei', u'My Cousin Vinny')
# (57L, 1993L, u'Anna Paquin', u'The Piano')
# (58L, 1994L, u'Dianne Wiest', u'Bullets over Broadway')
# (59L, 1995L, u'Mira Sorvino', u'Mighty Aphrodite')
# (60L, 1996L, u'Juliette Binoche', u'The English Patient')
# (61L, 1997L, u'Kim Basinger', u'L.A. Confidential')
# (62L, 1998L, u'Judi Dench', u'Shakespeare in Love')
# (63L, 1999L, u'Angelina Jolie', u'Girl, Interrupted')
# (64L, 2000L, u'Marcia Gay Harden', u'Pollock')
# (65L, 2001L, u'Jennifer Connelly', u'A Beautiful Mind')
# (66L, 2002L, u'Catherine Zeta-Jones', u'Chicago')
# (67L, 2003L, u'Ren\xe9e Zellweger', u'Cold Mountain')
# (68L, 2004L, u'Cate Blanchett', u'The Aviator')
# (69L, 2005L, u'Rachel Weisz', u'The Constant Gardener')
# (70L, 2006L, u'Jennifer Hudson', u'Dreamgirls')
# (71L, 2007L, u'Tilda Swinton', u'Michael Clayton')
# (72L, 2008L, u'Pen\xe9lope Cruz', u'Vicky Cristina Barcelona')
# (73L, 2009L, u"Mo'Nique", u'Precious')
# (74L, 2010L, u'Melissa Leo', u'The Fighter')
# (75L, 2011L, u'Octavia Spencer', u'The Help')
# (76L, 2012L, u'Anne Hathaway', u'Les Mis\xe9rables')
# (77L, 2013L, u"Lupita Nyong'o", u'12 Years a Slave')
# (78L, 2014L, u'Patricia Arquette', u'Boyhood')
# (79L, 2015L, u'Alicia Vikander', u'The Danish Girl')
# (80L, 2016L, u'Viola Davis', u'Fences')
# (81L, 2017L, u'Allison Janney', u'I, Tonya')

# %%
# Return a list of actors who have won more than 1 Oscar. In descending order
actor_mostWins = engine.execute("SELECT actor, COUNT(actor) AS total FROM best_actor GROUP BY actor HAVING total > 1 ORDER BY total DESC")
for x in actor_mostWins:
    print x
# Out:
# (u'Daniel Day-Lewis', 3L)
# (u'Emil Jannings', 2L)
# (u'Spencer Tracy', 2L)
# (u'Fredric March', 2L)
# (u'Gary Cooper', 2L)
# (u'Marlon Brando', 2L)
# (u'Dustin Hoffman', 2L)
# (u'Tom Hanks', 2L)
# (u'Jack Nicholson', 2L)
# (u'Sean Penn', 2L)

# %%
# Return a list of actresses who have won more than 1 Oscar. In descending order
actress_mostWins = engine.execute("SELECT actress, COUNT(actress) AS total FROM best_actress GROUP BY actress HAVING total > 1 ORDER BY total DESC")
for x in actress_mostWins:
    print x
# Out:
# (u'Katharine Hepburn', 4L)
# (u'Janet Gaynor', 3L)
# (u'Luise Rainer', 2L)
# (u'Bette Davis', 2L)
# (u'Olivia de Havilland', 2L)
# (u'Vivien Leigh', 2L)
# (u'Ingrid Bergman', 2L)
# (u'Elizabeth Taylor', 2L)
# (u'Glenda Jackson', 2L)
# (u'Jane Fonda', 2L)
# (u'Sally Field', 2L)
# (u'Jodie Foster', 2L)
# (u'Hilary Swank', 2L)
# (u'Meryl Streep', 2L)
# (u'Frances McDormand', 2L)

# %%
# Return a list of directors who have won more than 1 Oscar. In descending order
director_mostWins = engine.execute("SELECT director, COUNT(director) AS total FROM best_director GROUP BY director HAVING total > 1 ORDER BY total DESC")
for x in director_mostWins:
    print x
# Out:
# (u'John Ford', 4L)
# (u'Frank Capra', 3L)
# (u'William Wyler', 3L)
# (u'Frank Lloyd', 2L)
# (u'Leo McCarey', 2L)
# (u'Joseph L. Mankiewicz', 2L)
# (u'Elia Kazan', 2L)
# (u'George Stevens', 2L)
# (u'Billy Wilder', 2L)
# (u'David Lean', 2L)
# (u'Fred Zinnemann', 2L)
# (u'Milo\u0161 Forman', 2L)
# (u'Oliver Stone', 2L)
# (u'Steven Spielberg', 2L)
# (u'Clint Eastwood', 2L)
# (u'Ang Lee', 2L)
# (u'Alejandro G. I\xf1\xe1rritu', 2L)

# %%
# Return a list of supporting actors who have won more than 1 Oscar. In descending order
supActor_mostWins = engine.execute("SELECT actor, COUNT(actor) AS total FROM best_supporting_actor GROUP BY actor HAVING total > 1 ORDER BY total DESC")
for x in supActor_mostWins:
    print x
# Out:
# (u'Walter Brennan', 3L)
# (u'Anthony Quinn', 2L)
# (u'Peter Ustinov', 2L)
# (u'Jason Robards', 2L)
# (u'Melvyn Douglas', 2L)
# (u'Michael Caine', 2L)
# (u'Christoph Waltz', 2L)

# %%
# Return a list of supporting actresses who have won more than 1 Oscar. In descending order
actress_mostWins = engine.execute("SELECT actress, COUNT(actress) AS total FROM best_supporting_actress GROUP BY actress HAVING total > 1 ORDER BY total DESC")
for x in actress_mostWins:
    print x
# Out:
# (u'Shelley Winters', 2L)
# (u'Dianne Wiest', 2L)

# %%
# Return a list of best picture winning directors/companies in descending order of total wins
# This query is more complex because the nominee column can have multiple names in it. We are interested in the first name as
# that is usually the director. The names can be seperated by commas or 'and' so we use search for the position of the first comma.
# If a comma is found then use that as the maximum index for the substring. If not then search for the position of ' and ' and
# use that as the maximum index. Return the substring
picture_mostWins = engine.execute("SELECT \
IF (POSITION(',' IN nominee) > 0 , SUBSTRING(nominee, 1, POSITION(',' IN nominee) -1) , \
IF(POSITION(' and ' IN nominee) > 0, SUBSTRING(nominee, 1, POSITION(' and ' IN nominee)), nominee) \
) AS nominee, COUNT(nominee) AS total \
FROM best_picture GROUP BY nominee ORDER BY total DESC")
for x in picture_mostWins:
    print x
# Out:
# (u'Metro-Goldwyn-Mayer', 5L)
# (u'20th Century-Fox', 3L)
# (u'Sam Spiegel', 3L)
# (u'Columbia', 2L)
# (u'Selznick International Pictures', 2L)
# (u'Warner Bros.', 2L)
# (u'Paramount', 2L)
# (u'Arthur Freed', 2L)
# (u'Robert Wise', 2L)
# (u'Saul Zaentz', 2L)
# (u'Paramount Famous Lasky', 1L)
# (u'Universal', 1L)
# (u'RKO Radio', 1L)
# (u'Fox', 1L)
# (u'Samuel Goldwyn Productions', 1L)
# (u'J. Arthur Rank-Two Cities Films', 1L)
# (u'Robert Rossen Productions', 1L)
# (u'Cecil B. DeMille', 1L)
# (u'Buddy Adler', 1L)
# (u'Harold Hecht', 1L)
# (u'Michael Todd', 1L)
# (u'Sam Zimbalist', 1L)
# (u'Billy Wilder', 1L)
# (u'Tony Richardson', 1L)
# (u'Jack L. Warner', 1L)
# (u'Fred Zinnemann', 1L)
# (u'Walter Mirisch', 1L)
# (u'John Woolf', 1L)
# (u'Jerome Hellman', 1L)
# (u'Frank McCarthy', 1L)
# (u"Philip D'Antoni", 1L)
# (u'Albert S. Ruddy', 1L)
# (u'Tony Bill', 1L)
# (u'Francis Ford Coppola', 1L)
# (u'Michael Douglas ', 1L)
# (u'Irwin Winkler ', 1L)
# (u'Charles H. Joffe', 1L)
# (u'Barry Spikings', 1L)
# (u'Stanley R. Jaffe', 1L)
# (u'Ronald L. Schwary', 1L)
# (u'David Puttnam', 1L)
# (u'Richard Attenborough', 1L)
# (u'James L. Brooks', 1L)
# (u'Sydney Pollack', 1L)
# (u'Arnold Kopelson', 1L)
# (u'Jeremy Thomas', 1L)
# (u'Mark Johnson', 1L)
# (u'Richard D. Zanuck ', 1L)
# (u'Jim Wilson ', 1L)
# (u'Edward Saxon', 1L)
# (u'Clint Eastwood', 1L)
# (u'Steven Spielberg', 1L)
# (u'Wendy Finerman', 1L)
# (u'Mel Gibson', 1L)
# (u'James Cameron ', 1L)
# (u'David Parfitt', 1L)
# (u'Bruce Cohen ', 1L)
# (u'Douglas Wick', 1L)
# (u'Brian Grazer ', 1L)
# (u'Martin Richards', 1L)
# (u'Barrie M. Osborne', 1L)
# (u'Clint Eastwood', 1L)
# (u'Paul Haggis ', 1L)
# (u'Graham King', 1L)
# (u'Scott Rudin', 1L)
# (u'Christian Colson', 1L)
# (u'Kathryn Bigelow', 1L)
# (u'Iain Canning', 1L)
# (u'Thomas Langmann', 1L)
# (u'Grant Heslov', 1L)
# (u'Brad Pitt', 1L)
# (u'Alejandro G. I\xf1\xe1rritu', 1L)
# (u'Blye Pagon Faust', 1L)
# (u'Adele Romanski', 1L)
# (u'Guillermo del Toro ', 1L)
# C:\Users\Emmet\AppData\Roaming\Python\Python27\site-packages\sqlalchemy\engine\default.py:470: Warning: Column 'nominee' in group statement is ambiguous
#   cursor.execute(statement, parameters)
